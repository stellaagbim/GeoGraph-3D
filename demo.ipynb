# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#  GeoGraph-3D: Interactive Demo\n",
    "**Author:** Stella Agbim | **Research Project**\n",
    "\n",
    "Run this notebook to clone the repository, install dependencies, and visualize the Dynamic Graph CNN reconstruction of a 3D airplane."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# 1. Clone the Research Repository\n",
    "!git clone https://github.com/stellaagbim/GeoGraph-3D.git\n",
    "%cd GeoGraph-3D"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# 2. Install Research Dependencies (PyTorch Geometric)\n",
    "!pip install torch-scatter torch-sparse torch-cluster -f https://data.pyg.org/whl/torch-2.5.1+cu121.html\n",
    "!pip install plotly"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# 3. Run the Inference Engine\n",
    "from src.models import GeoGraph3D\n",
    "from src.visualize import visualize_inference\n",
    "import torch\n",
    "\n",
    "print(\" Environment Ready. Generating Manifold...\")\n",
    "visualize_inference()  # This generates the 3D Plot"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10.12"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
